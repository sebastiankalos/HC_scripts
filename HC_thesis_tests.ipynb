# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
F_lim = 0.5*1e4#LIDT [J/m^2]
E = 100e-3#eergy in the beam [J]
w_min = np.sqrt(2*E/(np.pi*F_lim)) #minimum required 1/e^2 intensity radius to keep fluence below F_lim; [m]

print(w_min*1e3)
# Out:
# 3.5682482323055424
